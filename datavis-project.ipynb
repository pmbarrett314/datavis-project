# %%
import random
import pandas
import bokeh
import bokeh.io

import numpy as np

from bokeh.plotting import figure,  show
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.models.annotations import Legend, LegendItem

# %%
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7c71cce1-7304-43df-98f6-b4c5e3212379">Loading BokehJS ...</span>
#     </div>

# %%
#read data
aoa=pandas.read_csv("data/AoA_ratings_Kuperman_et_al_BRM.csv")
semantics=pandas.read_csv("data/Parameters.csv")

# %%
# clean up input data
aoa.columns = map(str.lower, aoa.columns)
aoa = aoa.set_index("word")
aoa = aoa.drop("dunno",axis=1)


semantics["name"]=semantics["name"].str.lower()
semantics = semantics.drop("markup_description",axis=1)
semantics = semantics.drop("id",axis=1)
semantics = semantics.drop("pk",axis=1)
semantics = semantics.drop("jsondata",axis=1)
semantics = semantics.drop("representation",axis=1)

# %%
df = semantics.join(aoa, on="name")
df = df.dropna(subset=["rating.mean"])

df = df.rename(columns={
        'ontological_category': 'category', 
        'semanticfield': 'field', 
        'description': 'meaning', 
        'rating.mean': "mean", 
        'rating.sd': 'sd'})

semantic_fields=sorted(df["field"].unique())
ontological_categories=sorted(df["category"].unique())

df=df.set_index("name")

# %%
df.head(2)
# Out:
#                                                         meaning      category  \
# name
# contemptible                    Deserving of contempt or scorn.      Property
# dust          Any kind of solid material divided in particle...  Person/Thing
#
#                             field  occurtotal  occurnum  freq_pm   mean    sd
# name
# contemptible  Emotions and values        18.0      12.0     0.78  13.33  2.02
# dust           The physical world        18.0      18.0    23.84   5.06  1.39

# %%
mean = df["mean"]
category = df["category"]
field = df["field"]
sd=df["sd"]

radius = sd/25

color_choices = ["#FFFC31", "#5C415D", "#E94F37", "#5EB1BF"]

colors = [
    color_choices[ontological_categories.index(number)] for number in category
]

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,18), y_range=semantic_fields, plot_width=900, plot_height=700)

source = ColumnDataSource(
        data=dict(
            x=mean,
            y=field,
            name=df.index,
            radius=radius,
            sd=sd,
            colors=colors,
            age=df["mean"],
            desc=df["meaning"],
        )
    )

hover = HoverTool(
        tooltips=[
            ("Word", "@name"),
            ("Meaning", "@desc"),
            ("Age of Acquisition","@age"),
            ("Standard Deviation", "@sd"),
        ]
    )

renderers = [p.circle(0,0,fill_color=c) for c in color_choices]

legend_items = [LegendItem(label=ontological_categories[i], renderers=[renderers[i]]) for i in range(len(renderers))]
legend = Legend(items=legend_items)

p.add_tools(hover)

# add a circle renderer with vectorized colors and sizes
p.circle("x","y", radius="radius", source=source, fill_color="colors", fill_alpha=0.6, line_color=None, legend="legend")
p.legend.items=legend_items

# %%
# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bdd5647d-98bc-43ff-af34-81d7c9fc0bc7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#bdd5647d-98bc-43ff-af34-81d7c9fc0bc7").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bdd5647d-98bc-43ff-af34-81d7c9fc0bc7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bdd5647d-98bc-43ff-af34-81d7c9fc0bc7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c4d54965-e17b-467f-909d-7d6980492db5":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#5EB1BF"},"line_color":{"value":"#1f77b4"},"x":{"value":0},"y":{"value":0}},"id":"a7d2568e-9c5d-4ae5-b1fe-192cdd8f54b7","type":"Circle"},{"attributes":{},"id":"c1e923bd-998b-4805-86f6-092cfa5aec18","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"b5233714-ac91-4f7a-bab9-70c6e2c7d5bb","type":"Title"},{"attributes":{"callback":null,"overlay":{"id":"19f4c801-2e48-49e0-946e-ca5e0aeec766","type":"BoxAnnotation"},"plot":{"id":"844baa57-3e8e-49c9-bf0e-1c64a0553852","subtype":"Figure","type":"Plot"},"renderers":[{"id":"3719860f-e24f-429a-9a6b-a9dde8f00dfa","type":"GlyphRenderer"},{"id":"10814ed2-1c04-4ce4-bd6b-79c1ffedb26e","type":"GlyphRenderer"},{"id":"89a6ef6d-8b20-46b0-b834-fcc395620828","type":"GlyphRenderer"},{"id":"bb3b715a-4842-4dd3-89f7-440da2c6103a","type":"GlyphRenderer"},{"id":"200b8ed6-9f73-4a79-9d7f-62c9e0e730fa","type":"GlyphRenderer"}]},"id":"e1199412-410c-4ede-9c46-fde70bc08f0d","type":"BoxSelectTool"},{"attributes":{"label":{"value":"Person/Thing"},"renderers":[{"id":"89a6ef6d-8b20-46b0-b834-fcc395620828","type":"GlyphRenderer"}]},"id":"aa2df1ea-bd30-4625-bd05-caac4d335aa1","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#E94F37"},"line_color":{"value":"#1f77b4"},"x":{"value":0},"y":{"value":0}},"id":"a0f88d64-a389-4c7e-b2dc-a129e77f79bd","type":"Circle"},{"attributes":{"label":{"value":"Property"},"renderers":[{"id":"bb3b715a-4842-4dd3-89f7-440da2c6103a","type":"GlyphRenderer"}]},"id":"d13bddc4-beab-4c53-ab94-c6201bb923df","type":"LegendItem"},{"attributes":{"callback":null,"end":18},"id":"144a6b5b-9633-4385-9789-54713db39cb3","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"19f4c801-2e48-49e0-946e-ca5e0aeec766","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":0},"y":{"value":0}},"id":"2e77b9d0-9a50-42ef-a8d2-01b540581dc5","type":"Circle"},{"attributes":{},"id":"a2e793be-7aba-4132-a549-b158d9f09682","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"844baa57-3e8e-49c9-bf0e-1c64a0553852","subtype":"Figure","type":"Plot"}},"id":"ace706f6-37ad-4567-8f65-deaf2c00f6bf","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"3993d187-1c87-4721-8616-99627ade9b8e","type":"ColumnDataSource"},"glyph":{"id":"a0f88d64-a389-4c7e-b2dc-a129e77f79bd","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"d39e750b-f83b-45aa-842a-a7f58b1dda89","type":"Circle"},"selection_glyph":null},"id":"89a6ef6d-8b20-46b0-b834-fcc395620828","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"497f3150-a53d-4c46-87e8-27b5727684f1","type":"PolyAnnotation"},{"attributes":{"callback":null},"id":"3993d187-1c87-4721-8616-99627ade9b8e","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"59ca2c9c-7c10-49f4-a4ec-2f7e757daca1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":0},"y":{"value":0}},"id":"5a153506-92e4-49d9-ad55-d3728d7a5f9b","type":"Circle"},{"attributes":{"label":{"value":"Action/Process"},"renderers":[{"id":"3719860f-e24f-429a-9a6b-a9dde8f00dfa","type":"GlyphRenderer"}]},"id":"99877dd9-ef61-4de0-b091-d5579ddf0cc6","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"fie ...
